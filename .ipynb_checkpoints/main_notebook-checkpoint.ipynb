# %% [markdown]
# ### Can tidal forces and the Lidov-Kozai mechanism cause a system of exomoons to align in the same orbital plane?
#
# This script creates a system of the Sun + Jupiter + the Galilean moons, and runs a gravity code on them to investigate the moons change of eccentricity and inclination due to the Lidov-Koszai effect.
#
# The script is designed such that you can tell it which moons you'd like to include.

# %%
# Packages
import h5py
import time
import numpy as np
from amuse.lab import Particles
from amuse.couple import bridge
import matplotlib.pyplot as plt
from amuse.units.constants import G
from amuse.units import units, constants
from amuse.lab import Huayno, nbody_system
from amuse.community.ph4.interface import ph4
from amuse.ext.orbital_elements import get_orbital_elements_from_binary
from amuse.ext.orbital_elements import new_binary_from_orbital_elements

# %%
''' Function to create our particle system.
    Input: list of Galileann Moon names in string format (any combination of: io, europa, ganymede, callisto)
    Returns: Particle system 
    Example: system = system_with_moons(moons=['io', 'europa'], eccentricities=[0.4, 0.6], inclinations=[50, 60]) ''';

def system_with_moons(moons, eccentricities, inclinations, *args):
    
    
    # Assigning our variables
    x = zip(eccentricities, inclinations)
    y = list(x)
    z = {}
    for i in range(len(moons)):
        z[moons[i]] = y[i]   
    
    
    # Initialising Sun and Jupiter
    Msun = 1.0|units.MSun
    Mjup = 1.0|units.MJupiter
    a_jup = 5.2|units.au
    e_jup = 0.0
    
    system = new_binary_from_orbital_elements(Msun, Mjup, a_jup, e_jup, G=constants.G)
    system[0].name = 'sun'
    system[1].name = 'jupiter'
    jupiter = system[system.name=='jupiter']
    jupiter.semimajor_axis = a_jup
    
    
    # Function to automate addition of particles
    def add_particle(particle, a, e, inc, m):
        
        binary = new_binary_from_orbital_elements(jupiter.mass, m, a, eccentricity=e, inclination=inc, G=constants.G)
         
        system.add_particle(binary[1].as_set()) 
        system[-1].name = particle
        moon = system[system.name==particle] 
        
        moon.semimajor_axis = a
        moon.eccentricity = e
        moon.inclination = inc
        moon.position = binary[1].position + jupiter.position
        moon.velocity = binary[1].velocity + jupiter.velocity
        
        system.move_to_center()
    
    
    # Add moons based on input
    if 'io' in moons:
        a = 421800|units.km
        e = z['io'][0]
        inc = z['io'][1]|units.deg
        m = 8.93E22|units.kg
        add_particle('io', a, e, inc, m) 
    
    if 'europa' in moons:
        a = 671100|units.km
        e = z['europa'][0]
        inc = z['europa'][1]|units.deg
        m = 4.80E22|units.kg
        add_particle('europa', a, e, inc, m)  

    if 'ganymede' in moons:
        a = 1070400|units.km
        e = z['ganymede'][0]
        inc = z['ganymede'][1]|units.deg
        m = 1.48E23|units.kg
        add_particle('ganymede', a, e, inc, m)   
        
    if 'callisto' in moons:
        a = 1882700|units.km
        e = z['callisto'][0]
        inc = z['callisto'][1]|units.deg
        m = 1.08E23|units.kg
        add_particle('callisto', a, e, inc, m)  
        
    print('Particle system created for: '+ str(system.name))
    return system

# %%
# Testing

moons = ['io', 'europa', 'ganymede', 'callisto']
eccentricities = [0.3, 0.4, 0.5, 0.6]
inclinations = [40, 50, 60, 70]

system = system_with_moons(moons, eccentricities, inclinations)
# Out:
# Particle system created for: ['sun' 'jupiter' 'io' 'europa' 'ganymede' 'callisto']

# %%
# tidal forces

class TidalForce():
    def __init__(self, alpha=0.1):
        self.alpha=alpha
        
    
    def add_particles(self, particle_set):
        self.particles = particle_set
    
    
    def tidal_acceleration(self, k, alpha):
        R = (1|units.RJupiter).value_in(units.m) 
        M = (1|units.MJupiter).value_in(units.kg)
        G = constants.G.value_in( (units.m)**3 / (units.kg * units.s**2) )
        r = np.sqrt(np.sum(np.square(self.particles.position.value_in(units.m) - \
                                     self.particles[1].position.value_in(units.m)), axis=1))
        
        abs_vel = np.sqrt(np.sum(np.square(self.particles.velocity.value_in(units.m*units.s**-1)), axis=1))
        abs_acc = np.zeros(len(self.particles))
        mask = np.arange(len(self.particles)) != 1
        abs_acc[mask] = -9*k*G*self.particles.mass[mask].value_in(units.kg)*(R**5)*np.sin(2*alpha)/(4*r[mask]**7)
        abs_acc = abs_acc * 1|units.m*units.s**-2
                
        ax = abs_acc*(self.particles.vx.value_in(units.m*units.s**-1)/abs_vel)
        ay = abs_acc*(self.particles.vy.value_in(units.m*units.s**-1)/abs_vel)
        az = abs_acc*(self.particles.vz.value_in(units.m*units.s**-1)/abs_vel)
        
        return ax, ay, az
    
    
    def get_gravity_at_point(self, eps, x, y, z):
        return self.tidal_acceleration(k=0.565, alpha=self.alpha) #k from literature, alpha guess
    
def energy_dissipation(system,k=0.565,alpha=0.1):
    """ Calculates the total energy dissipation due to the tidal force for a particle system. The second
    particle in the particle set is the particle that exerts the tidal force."""
    #defining some constants
    R = (1|units.RJupiter).value_in(units.m) #radius of Jupiter
    M = (1|units.MJupiter).value_in(units.kg)
    G = constants.G.value_in( (units.m)**3 / (units.kg * units.s**2) )
    
    #getting some parameters/values from the particle set
    m = system.mass.value_in(units.kg)
    r = np.sqrt(np.sum(np.square(system.position.value_in(units.m) - \
                                 system[1].position.value_in(units.m)), axis=1))
    
    #to exclude the force of Jupiter on itself
    mask = np.arange(len(system)) != 1
    
    #the energy dissipation
    dE_dt = -9*k*G**(3/2)*M**(1/2)*m[mask]**2*R**5*np.sin(2*alpha)/(2*r[mask]**(15/2))
    
    return np.sum(dE_dt) * 1|units.J/units.s

def get_energies(system,timestep,k=0.565,alpha=0.1,):
    """ Calculates the total energy of the system, along with the energy dissipation."""
    #getting the kinetic and potential energy from the particle system
    E_kin = system.kinetic_energy()
    E_pot = system.potential_energy()
    E_tot = E_kin + E_pot
    
    #getting the energy dissipation
    dE_dt = energy_dissipation(system)
    #getting the total dissipated energy in the following timestep
    dE = dE_dt*timestep
    
    return E_tot, dE

# %%
''' Function to integrate the system over time using a gravity code.
    Input: list of Galileann Moon names in string format (any combination (but in order!) of: io, europa, ganymede, callisto),
            eccentricities, inclinations, integration time step, time range for integration
    Returns: list of evolved eccentrities, list of evolved inclinations, time range at time step intervals
    Example: ecc, inc, time_range = integrate_system(moons=['io'], eccentricities=[0.3], inclinations=[50],
            10|units.yr, 1000|units.yr) ''';

def integrate_system(moons, eccentricities, inclinations, dt, end_time):
    
    # Checking how long code takes to run
    start_time = time.time()
    
    # Getting system
    system = system_with_moons(moons, eccentricities, inclinations)
    
    # Converting Nbody
    converter = nbody_system.nbody_to_si(system.mass.sum(), system[1].position.length())
    
    # Gravity code
    gravity = Huayno(converter)
    gravity.particles.add_particles(system)
    
    # Eccentricities
    e_io = []
    e_eu = []
    e_ga = []
    e_ca = []
    
    # Inclinations
    i_io = [] | units.deg
    i_eu = [] | units.deg
    i_ga = [] | units.deg
    i_ca = [] | units.deg
    
    #Semimajor axes 
    a_io = [] | units.m
    a_eu = [] | units.m
    a_ga = [] | units.m
    a_ca = [] | units.m
    
    # Integration period
    time_range = [] | units.yr

    # Tidal force
    tf = TidalForce()
    tf.add_particles(system)
    
    # Bridge for tidal effects
    our_bridge = bridge.Bridge(use_threading=False)    
    our_bridge.add_system(gravity, (tf,))
    
    # Channels
    channel_grav = gravity.particles.new_channel_to(system)
    channel_tf = tf.particles.new_channel_to(system)
    
    E_tot = []
    E_dissipation = []
    
    # Running gravity code
    model_time = np.arange(0, end_time.value_in(units.yr), dt.value_in(units.yr)) * 1|units.yr
    
    for tstep in model_time:
        
        if 'io' in moons:
            orbit_io = get_orbital_elements_from_binary(system[(system.name=='jupiter')|(system.name=='io')],
                                                        G=constants.G)
            
        if 'europa' in moons:
            orbit_eu = get_orbital_elements_from_binary(system[(system.name=='jupiter')|(system.name=='europa')],
                                                        G=constants.G)
            
        if 'ganymede' in moons:
            orbit_ga = get_orbital_elements_from_binary(system[(system.name=='jupiter')|(system.name=='ganymede')],
                                                        G=constants.G)
            
        if 'callisto' in moons:
            orbit_ca = get_orbital_elements_from_binary(system[(system.name=='jupiter')|(system.name=='callisto')],
                                                        G=constants.G)
        
        
        our_bridge.evolve_model(tstep)
        channel_grav.copy()
        channel_tf.copy()
        
        E, E_diss = get_energies(system,dt)
        E_tot.append(E.value_in(units.J))
        E_dissipation.append(E_diss.value_in(units.J))
        
        if 'io' in moons:
            a_io.append(orbit_io[2])
            e_io.append(orbit_io[3])
            i_io.append(orbit_io[5])
            
        
        if 'europa' in moons:
            a_eu.append(orbit_eu[2])
            e_eu.append(orbit_eu[3])
            i_eu.append(orbit_eu[5])
            
        
        if 'ganymede' in moons:
            a_ga.append(orbit_ga[2])
            e_ga.append(orbit_ga[3])
            i_ga.append(orbit_ga[5])
            
        
        if 'callisto' in moons:
            a_ca.append(orbit_ca[2])
            e_ca.append(orbit_ca[3])
            i_ca.append(orbit_ca[5])
        
        
    our_bridge.stop()
    
    
    ecc = []
    inc = [] | units.deg
    sma = [] | units.m
    
    if 'io' in moons:
        ecc.append(e_io)
        inc.append(i_io)
        sma.append(a_io)
        
    if 'europa' in moons:
        ecc.append(e_eu)
        inc.append(i_eu)
        sma.append(a_eu)
        
    if 'ganymede' in moons:
        ecc.append(e_ga)
        inc.append(i_ga)
        sma.append(a_ga)
        
    if 'callisto' in moons:
        ecc.append(e_ca)
        inc.append(i_ca)
        sma.append(a_ca)
        
    
    # Printing runtime
    print('Runtime: %s seconds' % (time.time() - start_time))
    
    
    return ecc, inc, model_time, sma, E_tot, E_dissipation

# %%
# Running code

moons = ['io', 'europa', 'ganymede', 'callisto']
eccentricities = [0.3, 0.4, 0.5, 0.6]
inclinations = [40, 50, 60, 70]

ecc, inc, time_range, sma, Etot, Ediss = integrate_system(moons, eccentricities, inclinations, 10|units.yr, 1000|units.yr)
# Out:
# Particle system created for: ['sun' 'jupiter' 'io' 'europa' 'ganymede' 'callisto']
# Runtime: 7.920401096343994 seconds

# %%
# Conditions for Lidov-Kozai to take effect: ~ 40-140 deg inclinations
# We will test 30-150 deg inclinations in steps of 10 deg (13 values)
# We will test eccentricities in steps of 0.08 starting from 0.0 (13 values)
# 5000 years with dt=100 gives runtime ~ 90 seconds

def param_space(moons):
    
    start_time = time.time()
    filename  = 'results.hdf5'
    results = h5py.File(filename, 'w')
    
    dt = 100|units.yr
    end_time = 5000|units.yr
    
    all_inc = np.arange(30, 160, 10)
    all_ecc = np.arange(0.0, 1.0, 0.08)
    
    for i in range(len(all_ecc)):
        print('inc='+str(all_inc[i]))
        g1 = results.create_group('inc='+str(all_inc[i]))
        for j in range(len(all_ecc)):
            ecc, inc, time_range, sma, Etot, diss = integrate_system(moons, [all_ecc[j]], [all_inc[i]], dt, end_time)
            g2 = g1.create_group('ecc='+str(all_ecc[j]))
            g2['inc'] = inc[0].value_in(units.deg)
            g2['ecc'] = ecc[0]
            g2['sma'] = sma[0].value_in(units.m)
            g2['Etot'] = Etot
            g2['diss'] = diss
        print('')
        
    results.close()
    print('\nTotal runtime: %s hours' % ((time.time() - start_time)/3600))

# %%
moons = ['europa']
param_space(moons)
# Out:
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7679171562194824 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7842068672180176 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.805220365524292 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7477819919586182 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7737143039703369 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7513375282287598 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7997875213623047 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8720893859863281 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7892782688140869 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7799649238586426 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8134756088256836 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.9837157726287842 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.6260600090026855 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7112295627593994 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7801344394683838 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8232154846191406 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7957727909088135 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7822771072387695 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7694051265716553 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7938704490661621 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7998147010803223 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8287618160247803 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7866358757019043 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.82466721534729 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 1.0227985382080078 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.6235067844390869 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7633106708526611 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7606215476989746 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8148231506347656 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7614345550537109 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.753821611404419 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7528810501098633 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7791078090667725 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7995874881744385 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7808001041412354 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8018298149108887 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8196661472320557 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.95835280418396 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.6108341217041016 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7347733974456787 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7506613731384277 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7743721008300781 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8054475784301758 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7787652015686035 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8321559429168701 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8227565288543701 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8122158050537109 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.88555908203125 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7975864410400391 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.818540096282959 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 1.0060241222381592 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.6106739044189453 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7285659313201904 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7746422290802002 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7786118984222412 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7632565498352051 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8009068965911865 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7874720096588135 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8045849800109863 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8026809692382812 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8098294734954834 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7950010299682617 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8221793174743652 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.9782280921936035 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.6116166114807129 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7624921798706055 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7994716167449951 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7845008373260498 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7922549247741699 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.794529914855957 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7872531414031982 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8211398124694824 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.807694673538208 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8031165599822998 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8498513698577881 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.865985631942749 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 1.0225021839141846 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.6187694072723389 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7514302730560303 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8025152683258057 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7902841567993164 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7823200225830078 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.785693883895874 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7688419818878174 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8659400939941406 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8091413974761963 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.9073846340179443 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8247740268707275 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8327498435974121 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.9938094615936279 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.6392958164215088 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7747728824615479 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7707383632659912 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7964832782745361 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7812552452087402 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7765564918518066 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8007848262786865 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8181679248809814 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8081555366516113 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7939560413360596 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8041205406188965 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8412206172943115 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.9760057926177979 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.6201753616333008 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7473986148834229 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7917270660400391 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8247952461242676 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8484001159667969 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8300232887268066 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8248472213745117 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8272764682769775 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8385367393493652 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8440511226654053 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7959206104278564 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8642728328704834 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.9975478649139404 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.6327033042907715 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7825276851654053 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7938792705535889 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.795795202255249 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7805783748626709 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8005635738372803 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.799736499786377 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8102760314941406 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8590595722198486 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7809689044952393 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8159797191619873 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8356719017028809 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 1.010645866394043 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.695669412612915 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7386579513549805 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8305225372314453 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8195064067840576 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8087785243988037 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7881886959075928 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7976212501525879 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8250811100006104 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8190822601318359 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8784289360046387 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8569746017456055 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.861685037612915 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 1.033414602279663 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.649240255355835 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7906229496002197 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8004975318908691 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7775423526763916 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8141279220581055 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8464310169219971 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8539924621582031 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8856303691864014 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8481271266937256 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8659162521362305 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8583955764770508 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.877866268157959 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 1.0332860946655273 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.6620376110076904 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7956254482269287 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8335957527160645 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8137416839599609 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8020784854888916 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8196637630462646 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.7959253787994385 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8184182643890381 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8425045013427734 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8664615154266357 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.9483368396759033 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.8594012260437012 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 1.030726432800293 seconds
# Particle system created for: ['sun' 'jupiter' 'europa']
# Runtime: 0.6843187808990479 seconds

# %%
res = h5py.File('results.hdf5')

plt.figure(figsize=[10,6], facecolor='w')
plt.title('Inclination = 60 deg')
plt.xlabel('Time [yr]')
plt.ylabel('Eccentricity')

model_time = np.arange(0, 10, 1)

x = list(res['inc=100'].keys())
for i in range(len(x)-1):
    plt.plot(model_time, res['inc=70'][x[i]]['ecc'][:], label=x[i])
    
plt.legend(bbox_to_anchor=(1, 0.95))
plt.show()

# %%
def plot_tracks(moons, ecc, inc, time_range, sma):
    
    plt.rcParams.update({'font.size': 20})
    fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=[20, 15], tight_layout=True)
    colours = ['r', 'g', 'b', 'm']

    for i in range(len(moons)):
        ax1.plot(time_range.value_in(units.yr), inc[i].value_in(units.deg), color=colours[i], label=moons[i])   
    ax1.set_ylabel('Inclination [deg]')
    ax1.legend()

    for i in range(len(moons)):
        ax2.plot(time_range.value_in(units.yr), np.array(ecc[i]), color=colours[i], label=moons[i])   
    ax2.set_ylabel('Eccentricity')
    ax2.set_xlabel('Time [years]')
    ax2.legend()
    
    for i in range(len(moons)):
        ax3.plot(time_range.value_in(units.yr), sma[i].value_in(units.m), color=colours[i], label=moons[i])   
    ax3.set_ylabel('Semimajor Axis')
    ax3.set_xlabel('Time [years]')
    ax3.legend()    
    
    plt.suptitle('Huayno Code (dt=10yrs)')
    plt.subplots_adjust(top=0.94)
    #plt.savefig('10000.png', facecolor='w', bbox_inches='tight')
    plt.show()

# %%
plot_tracks(moons, ecc, inc, time_range, sma)

# %%
''' The Kozai-constant Lz should be (approximately) conserved. This function will check this by computing Lz.
    Input: list of eccentricites and inclinations obtained from the integrate_system() function
    Returns: array of Lz's for each instance for each moon, and plots!
    Example: lz = check_lz(ecc, inc) '''
    
def check_lz(ecc, inc, moons):
    
    start_time = time.time()
    
    # Lz=sqrt(1-e**2)*cos(i)
    lz = np.zeros_like(ecc)
    for i in range(len(lz[0])):
        for j in range(len(lz[0:])):
            x = np.sqrt(1 - ecc[j][i]**2) * np.cos(inc[j][i].value_in(units.rad))
            lz[j][i] = x
    
    # Standard deviations
    sdev = []
    for i in range(len(lz[0:])):
        y = np.std(lz[i:])
        sdev.append(y)
    
    # Plotting
    colours = ['r', 'g', 'b', 'm']     
    plt.rcParams.update({'font.size': 20})
    
    # Sizes of subplots are annoying
    if len(lz[0:]) < 4:
        figsize=[10,8]
    else:
        figsize=[10,12]
    
    fig, ax = plt.subplots(len(lz[0:]), 1, figsize=figsize, constrained_layout=True)    
    
    for i, ax in enumerate(fig.axes):
        ax.plot(time_range.value_in(units.yr), lz[i], '-o', color=colours[i], lw=1, label=moons[i])
        ax.plot([], [], ' ', label='std = '+str(round(sdev[i],3)))
        ax.legend(fontsize=16) 
        
    plt.suptitle('Lz vs Time')
    #plt.subplots_adjust(top=0.94)
    plt.show()
    
    # Runtime
    print('Runtime: %s seconds' % (time.time() - start_time))
                           
    return lz

# %%
res = h5py.File('test.hdf5')

res['inc=2']['inc'][:]

res.close()

# %%
lz = check_lz(ecc, inc, moons)

# %%
def plot_tidal_dissipation(Etot, time_range, moons):
    
    # Plotting
    colours = ['r', 'g', 'b', 'm']     
    plt.rcParams.update({'font.size': 20})
    
    # Sizes of subplots are annoying
    if len(td[0:]) < 4:
        figsize=[10,8]
    else:
        figsize=[10,12]
    
    fig, ax = plt.subplots(len(td[0:]), 1, figsize=figsize, constrained_layout=True)     
    
    for i, ax in enumerate(fig.axes):
        ax.plot(time_range.value_in(units.yr), Ediss,'-o', color=colours[i], lw=1, label=moons[i])
        ax.legend(fontsize=16) 
        
    plt.suptitle('Total Energy vs Time')
    #plt.subplots_adjust(top=0.94)
    plt.show()

# %%
plot_tidal_dissipation(Etot, time_range, moons)

# %%
a = np.arange(1,6,2)
b = np.copy(a) * 2

t1 = []
t2 = []
for i in range(len(a)):
    for j in range(len(a)):
        x = a[i]*b[j]
        y = a[j]*b[i]
        t1.append(x)
        t2.append(x)

# %%
t1
# Out:
# [2, 6, 10, 6, 18, 30, 10, 30, 50]

# %%
data = np.arange(30, 160, 10)

# %%
test.close()

# %%
test = h5py.File('test.hdf5', 'w')

dest = test.create_dataset('d2', data)
test.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_10604/3869444808.py in <module>
#       1 test = h5py.File('test.hdf5', 'w')
#       2
# ----> 3 dest = test.create_dataset('d2', data)
#       4 test.close()
#
# ~/Amuse-env/lib/python3.8/site-packages/h5py/_hl/group.py in create_dataset(self, name, shape, dtype, data, **kwds)
#     147                     group = self.require_group(parent_path)
#     148
# --> 149             dsid = dataset.make_new_dset(group, shape, dtype, data, name, **kwds)
#     150             dset = dataset.Dataset(dsid)
#     151             return dset
#
# ~/Amuse-env/lib/python3.8/site-packages/h5py/_hl/dataset.py in make_new_dset(parent, shape, dtype, data, name, chunks, compression, shuffle, fletcher32, maxshape, compression_opts, fillvalue, scaleoffset, track_times, external, track_order, dcpl, allow_unknown_filter)
#     135
#     136
# --> 137     dset_id = h5d.create(parent.id, name, tid, sid, dcpl=dcpl)
#     138
#     139     if (data is not None) and (not isinstance(data, Empty)):
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5d.pyx in h5py.h5d.create()
#
# ValueError: Unable to create dataset (unable to retrieve number of elements in dataspace)

# %%
t2
# Out:
# [2, 6, 10, 6, 18, 30, 10, 30, 50]
